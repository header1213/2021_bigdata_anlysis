# %% [markdown]
# # 01. matplotlib이란?
# * matplotlib은 파이썬 기반의 시각화 라이브러리 (seaborn, folium)
# * 다양한 형태의 그래프(플롯)를 그릴 때 사용함
# * https://matplotlib.org/
# * https://github.com/matplotlib/matplotlib
# * matplotlib cheat sheet 참고

# %%
# !pip install --upgrade --user matplotlib

# %%
import matplotlib as mpl

# %%
mpl.__version__
# Out:
# '3.5.0'

# %%
import matplotlib.pyplot as plt

# %%
# (0, 0) ~ (4, 16)
x = [0, 1, 2, 3, 4]
y = [0, 1, 4, 9, 16]
plt.plot(x, y)  # 그래프 그리기

# %%
# x좌표 데이터 생략 시 x값은 0 ~ N-1까지 실행
plt.plot(x)
plt.show()

# %%
plt.plot([0, 2, 8, 18, 32, 50, 72, 98])
