# %% [markdown]
# # OP.GG 플레이어 전적 크롤링
# * 특정 소환사(플레이어)의 게임 전적을 크롤링
# * https://www.op.gg/summoner/userName={nickname} (https://www.op.gg/summoner/userName=아니어떡하라구요)

# %% [markdown]
# ### requests로 전적 페이지 받아오기

# %%
import requests

headers = {
    'accept-language': 'ko'
}
nickname = '아니어떡하라구요'  # 2325 이상인
url = f'https://www.op.gg/summoner/userName={nickname}'
res = requests.get(url, headers=headers)
res
# Out:
# <Response [200]>

# %% [markdown]
# ### BeautifulSoup으로 soup 만들기

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(res.text, 'html.parser')
print(soup.prettify()[:500])
# Out:
# <!DOCTYPE html>
# <!--
# 	  ,ad8888ba,   88888888ba         ,ad8888ba,    ,ad8888ba,
# 	 d8"'    `"8b  88      "8b       d8"'    `"8b  d8"'    `"8b
# 	d8'        `8b 88      ,8P      d8'           d8'
# 	88          88 88aaaaaa8P'      88            88
# 	88          88 88""""""'        88      88888 88      88888
# 	Y8,        ,8P 88               Y8,        88 Y8,        88
# 	 Y8a.    .a8P  88                Y8a.    .a88  Y8a.    .a88
# 	  `"Y8888Y"'   88     dev@op.gg   `"Y88888P"    `"Y88888P"
#
# 		 Copyright

# %% [markdown]
# ### 각 게임을 soup.select로 가져오기

# %%
games = soup.select('.GameItemWrap > .GameItem')
# print(games[0])

# %% [markdown]
# ### 게임 결과 받아오기

# %%
result = []
for game in games:
    result.append(['패배', '승리'][game['data-game-result'] == 'win'])
    # data-game-result가 win이면 '승리', 아니면 '패배'
result[:5]
# Out:
# ['패배', '승리', '패배', '승리', '패배']

# %% [markdown]
# ### 플레이한 챔피언 이름 가져오기

# %%
champ = []
for game in games:
    champ.append(game.find(class_='ChampionName').get_text().strip())
champ[:5]
# Out:
# ['오른', '볼리베어', '오른', '볼리베어', '파이크']

# %% [markdown]
# ### Kill/Death/Assist 가져오기

# %%
kda = []
for game in games:
    kda.append('/'.join([i.get_text() for i in game.select('.KDA > .KDA > *')]))
    # .KDA > .KDA 의 요소로 있는 K, D, A 각각을 /로 구분
kda[:5]
# Out:
# ['0/6/3', '3/5/3', '1/9/4', '5/6/5', '6/9/5']

# %% [markdown]
# ### 사용한 아이템 가져오기

# %%
item = []
for game in games:
    item.append(', '.join([i['alt'] for i in game.select('.Items > .ItemList > .Item:not(:nth-child(4)) > img')]))
    # 4번째 아이템은 장신구(와드 및 허수아비, 칼리스타의 창 등)이므로 제외
item[:5]
# Out:
# ['도란의 방패, 거인의 허리띠, 점화석, 덤불 조끼, 판금 장화',
#  '도란의 검, 신성한 파괴자, 루비 수정, 탐식의 망치, 곡괭이, 헤르메스의 발걸음',
#  '덤불 조끼, 서리벼림 손아귀, 증오의 사슬, 판금 장화',
#  '스테락의 도전, 신성한 파괴자, 판금 장화, 덤불 조끼',
#  '드락사르의 황혼검, 징수의 총, 톱날 단검, 명석함의 아이오니아 장화']

# %% [markdown]
# ### 사용한 룬 가져오기

# %%
rune = []
for game in games:
    gameid = game['data-game-id']
    summonerid = game['data-summoner-id']
    # gameid, summonerid를 받아옴
    url = f'https://www.op.gg/summoner/matches/ajax/detail/builds/gameId={gameid}&summonerId={summonerid}&moreLoad=1'
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, 'html.parser')
    # 빌드를 보여주는 ajax를 받아와 soup를 만듦
    rune.append(soup.select_one('.perk-page__item--keystone.perk-page__item--active img')['alt'])
    # keystone(핵심 룬) 중 active(활성화된)인 룬을 가져옴
rune[:5]
# Out:
# ['봉인 풀린 주문서', '집중 공격', '봉인 풀린 주문서', '집중 공격', '어둠의 수확']

# %% [markdown]
# ### DataFrame 만들기

# %%
import pandas as pd

df_data = {
    'result': result,
    'champ': champ,
    'kda': kda,
    'item': item,
    'rune': rune
}
df = pd.DataFrame(df_data)
df
# Out:
#    result champ       kda                                               item  \
# 0      패배    오른     0/6/3                 도란의 방패, 거인의 허리띠, 점화석, 덤불 조끼, 판금 장화
# 1      승리  볼리베어     3/5/3      도란의 검, 신성한 파괴자, 루비 수정, 탐식의 망치, 곡괭이, 헤르메스의 발걸음
# 2      패배    오른     1/9/4                     덤불 조끼, 서리벼림 손아귀, 증오의 사슬, 판금 장화
# 3      승리  볼리베어     5/6/5                     스테락의 도전, 신성한 파괴자, 판금 장화, 덤불 조끼
# 4      패배   파이크     6/9/5             드락사르의 황혼검, 징수의 총, 톱날 단검, 명석함의 아이오니아 장화
# 5      패배  볼리베어    4/8/10             가시 갑옷, 신성한 파괴자, 헤르메스의 발걸음, 곡괭이, 탐식의 망치
# 6      승리    오른    2/3/12      덤불 조끼, 터보 충전 마공학 실험장치, 증오의 사슬, 거인의 허리띠, 판금 장화
# 7      승리    오른    3/3/14  도란의 방패, 터보 충전 마공학 실험장치, 증오의 사슬, 가시 갑옷, 얼음 방패, ...
# 8      패배   아크샨     9/7/3  도란의 검, 크라켄 학살자, 마법사의 최후, 몰락한 왕의 검, 톱날 단검, 광전사의 군화
# 9      승리    티모    13/7/6   도란의 반지, 내셔의 이빨, 균열 생성기, 악마의 포옹, 마법사의 최후, 광전사의 군화
# 10     패배    오른     3/6/1      덤불 조끼, 마법무효화의 망토, 증오의 사슬, 바미의 불씨, 천 갑옷, 판금 장화
# 11     승리    오른     8/0/6       도란의 방패, 터보 충전 마공학 실험장치, 증오의 사슬, 가시 갑옷, 판금 장화
# 12     승리    오른     3/3/9  가시 갑옷, 터보 충전 마공학 실험장치, 증오의 사슬, 파수꾼의 갑옷, 얼음 방패,...
# 13     승리    오른     3/0/2            도란의 방패, 바미의 불씨, 증오의 사슬, 천 갑옷, 헤르메스의 발걸음
# 14     패배    오른   11/7/12  증오의 사슬, 터보 충전 마공학 실험장치, 가고일 돌갑옷, 가시 갑옷, 워모그의 갑...
# 15     패배    직스    7/6/10          리안드리의 고뇌, 마법사의 신발, 악마의 포옹, 여신의 눈물, 증폭의 고서
# 16     패배    오른    7/5/12  가시 갑옷, 란두인의 예언, 얼어붙은 심장, 판금 장화, 서리벼림 손아귀, 수정 팔...
# 17     승리    케일  14/16/38  균열 생성기, 내셔의 이빨, 헤르메스의 발걸음, 몰락한 왕의 검, 리치베인, 마법사...
# 18     패배    티모    4/11/9  균열 생성기, 존야의 모래시계, 내셔의 이빨, 마법사의 최후, 거인의 허리띠, 광전...
# 19     패배    티모   7/12/20  균열 생성기, 존야의 모래시계, 리치베인, 내셔의 이빨, 거인의 허리띠, 명석함의 ...
#
#          rune
# 0   봉인 풀린 주문서
# 1       집중 공격
# 2   봉인 풀린 주문서
# 3       집중 공격
# 4      어둠의 수확
# 5       집중 공격
# 6   봉인 풀린 주문서
# 7   봉인 풀린 주문서
# 8       집중 공격
# 9       집중 공격
# 10    착취의 손아귀
# 11    착취의 손아귀
# 12  봉인 풀린 주문서
# 13  봉인 풀린 주문서
# 14  봉인 풀린 주문서
# 15    신비로운 유성
# 16  봉인 풀린 주문서
# 17      집중 공격
# 18      집중 공격
# 19     어둠의 수확

# %% [markdown]
# ## Riot API를 통해 더 자세한 정보 가져오기

# %%
api_key = 'RGAPI-3bb7d59a-d4d3-4096-8f7e-7142ea3c99ae'

# %% [markdown]
# * api_key는 24시간마다 만료되므로 https://developer.riotgames.com/ 에서 매일 발급받거나 Product Key를 발급받아 사용해야 함

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.229 Whale/2.10.123.42 Safari/537.36",
    "Accept-Language": "ko,en;q=0.9",
    "Accept-Charset": "application/x-www-form-urlencoded; charset=UTF-8",
    "Origin": "https://developer.riotgames.com",
    "X-Riot-Token": api_key
}

# %% [markdown]
# ### 소환사 정보 가져오기

# %%
url = f'https://kr.api.riotgames.com/lol/summoner/v4/summoners/by-name/{nickname}'
summoner = requests.get(url, headers=headers).json()
summonerName = summoner['name']
summonerName
# Out:
# '아니어떡하라구요'

# %% [markdown]
# ### 최근 매치 20개 가져오기

# %%
puuid = summoner['puuid']
url = f'https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?count=20'
matches = requests.get(url, headers=headers).json()
matches
# Out:
# ['KR_5448429896',
#  'KR_5448372800',
#  'KR_5447315779',
#  'KR_5434421745',
#  'KR_5430983106',
#  'KR_5430678306',
#  'KR_5430125962',
#  'KR_5430051788',
#  'KR_5428974331',
#  'KR_5428859656',
#  'KR_5428866873',
#  'KR_5428942849',
#  'KR_5428728773',
#  'KR_5428499419',
#  'KR_5428543169',
#  'KR_5427423152',
#  'KR_5427267921',
#  'KR_5427247722',
#  'KR_5427117386',
#  'KR_5427065229']

# %% [markdown]
# ### 가져온 데이터 확인

# %%
url = f'https://asia.api.riotgames.com/lol/match/v5/matches/{matches[0]}'
match = requests.get(url, headers=headers).json()
participants = match['info']['participants']
participants[0]
# Out:
# {'assists': 3,
#  'baronKills': 0,
#  'bountyLevel': 0,
#  'champExperience': 6582,
#  'champLevel': 10,
#  'championId': 516,
#  'championName': 'Ornn',
#  'championTransform': 0,
#  'consumablesPurchased': 1,
#  'damageDealtToBuildings': 0,
#  'damageDealtToObjectives': 0,
#  'damageDealtToTurrets': 0,
#  'damageSelfMitigated': 10217,
#  'deaths': 6,
#  'detectorWardsPlaced': 0,
#  'doubleKills': 0,
#  'dragonKills': 0,
#  'firstBloodAssist': True,
#  'firstBloodKill': False,
#  'firstTowerAssist': False,
#  'firstTowerKill': False,
#  'gameEndedInEarlySurrender': False,
#  'gameEndedInSurrender': True,
#  'goldEarned': 4197,
#  'goldSpent': 3800,
#  'individualPosition': 'TOP',
#  'inhibitorKills': 0,
#  'inhibitorTakedowns': 0,
#  'inhibitorsLost': 0,
#  'item0': 1054,
#  'item1': 1011,
#  'item2': 3067,
#  'item3': 3076,
#  'item4': 3047,
#  'item5': 0,
#  'item6': 3340,
#  'itemsPurchased': 10,
#  'killingSprees': 0,
#  'kills': 0,
#  'lane': 'NONE',
#  'largestCriticalStrike': 2,
#  'largestKillingSpree': 0,
#  'largestMultiKill': 0,
#  'longestTimeSpentLiving': 254,
#  'magicDamageDealt': 11408,
#  'magicDamageDealtToChampions': 2319,
#  'magicDamageTaken': 2418,
#  'neutralMinionsKilled': 0,
#  'nexusKills': 0,
#  'nexusLost': 0,
#  'nexusTakedowns': 0,
#  'objectivesStolen': 0,
#  'objectivesStolenAssists': 0,
#  'participantId': 1,
#  'pentaKills': 0,
#  'perks': {'statPerks': {'defense': 5002, 'flex': 5002, 'offense': 5007},
#   'styles': [{'description': 'primaryStyle',
#     'selections': [{'perk': 8360, 'var1': 4, 'var2': 0, 'var3': 0},
#      {'perk': 8304, 'var1': 10, 'var2': 3, 'var3': 0},
#      {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#      {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#     'style': 8300},
#    {'description': 'subStyle',
#     'selections': [{'perk': 8446, 'var1': 0, 'var2': 0, 'var3': 0},
#      {'perk': 8473, 'var1': 1058, 'var2': 0, 'var3': 0}],
#     'style': 8400}]},
#  'physicalDamageDealt': 18373,
#  'physicalDamageDealtToChampions': 1698,
#  'physicalDamageTaken': 8642,
#  'profileIcon': 4931,
#  'puuid': 'HyUnC4dVN-bpotgrPhkgGx49p6b1P5T5rvoq-QFhK7BINfJbOwN6un-4T_YsHc-65M_dOpJXVO5KVw',
#  'quadraKills': 0,
#  'riotIdName': '',
#  'riotIdTagline': '',
#  'role': 'SUPPORT',
#  'sightWardsBoughtInGame': 0,
#  'spell1Casts': 32,
#  'spell2Casts': 25,
#  'spell3Casts': 21,
#  'spell4Casts': 6,
#  'summoner1Casts': 4,
#  'summoner1Id': 12,
#  'summoner2Casts': 5,
#  'summoner2Id': 3,
#  'summonerId': 'Ms39QlcUeNWBer5LxYH-MQcsFQBmt3wkxQYXWD0MsOXm2Uo',
#  'summonerLevel': 93,
#  'summonerName': '아니어떡하라구요',
#  'teamEarlySurrendered': False,
#  'teamId': 100,
#  'teamPosition': 'TOP',
#  'timeCCingOthers': 21,
#  'timePlayed': 964,
#  'totalDamageDealt': 40406,
#  'totalDamageDealtToChampions': 4017,
#  'totalDamageShieldedOnTeammates': 0,
#  'totalDamageTaken': 13612,
#  'totalHeal': 165,
#  'totalHealsOnTeammates': 0,
#  'totalMinionsKilled': 81,
#  'totalTimeCCDealt': 242,
#  'totalTimeSpentDead': 155,
#  'totalUnitsHealed': 1,
#  'tripleKills': 0,
#  'trueDamageDealt': 10625,
#  'trueDamageDealtToChampions': 0,
#  'trueDamageTaken': 2550,
#  'turretKills': 0,
#  'turretTakedowns': 0,
#  'turretsLost': 4,
#  'unrealKills': 0,
#  'visionScore': 7,
#  'visionWardsBoughtInGame': 0,
#  'wardsKilled': 2,
#  'wardsPlaced': 3,
#  'win': False}

# %% [markdown]
# ### 각 매치의 데이터를 받아와 저장

# %%
matchlist = []
for matchid in matches:
    url = f'https://asia.api.riotgames.com/lol/match/v5/matches/{matchid}'
    match = requests.get(url, headers=headers).json()
    matchlist.append(match)

# %%
mode = []  # 게임 모드
role = []  # 게임 내 역할(및 라인)
champ = []  # 챔피언 이름
level = []  # 레벨
gold = []  # 얻은 골드
cs = []  # 처치한 미니언
vision = []  # 시야 점수
deal = []  # 챔피언에게 입힌 피해량
win = []  # 승리 여부
for match in matchlist:
    participants = match['info']['participants']
    for p in participants:
        if p['summonerName'] == summonerName:
            mode.append(f"{match['info']['gameMode']} {match['info']['gameType']}")
            position = p['individualPosition']
            if position == 'Invalid':
                position = p['lane']
                if position == 'NONE':
                    position = ''
            role.append(f"{position} {p['role']}".strip())
            champ.append(p['championName'])
            level.append(p['champLevel'])
            gold.append(p['goldEarned'])
            cs.append(p['totalMinionsKilled'])
            vision.append(p['visionScore'])
            deal.append(p['totalDamageDealtToChampions'])
            win.append(p['win'])
            break
win
# Out:
# [False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False]

# %% [markdown]
# ### DataFrame 만들기

# %%
df_data = {
    'mode': mode,
    'role': role,
    'champ': champ,
    'level': level,
    'gold': gold,
    'cs': cs,
    'vision': vision,
    'deal': deal,
    'win': win
}
df2 = pd.DataFrame(df_data)
df2
# Out:
#                     mode            role     champ  level   gold   cs  vision  \
# 0   CLASSIC MATCHED_GAME     TOP SUPPORT      Ornn     10   4197   81       7
# 1   CLASSIC MATCHED_GAME        TOP SOLO  Volibear     15   8776  136      15
# 2   CLASSIC MATCHED_GAME        TOP SOLO      Ornn     13   7749  124      21
# 3   CLASSIC MATCHED_GAME        TOP SOLO  Volibear     14   8859  105      13
# 4      ARAM MATCHED_GAME         SUPPORT      Pyke     12   8832    5       0
# 5   CLASSIC MATCHED_GAME        TOP SOLO  Volibear     15   9512  121      14
# 6   CLASSIC MATCHED_GAME        TOP SOLO      Ornn     15   8485  110       6
# 7   CLASSIC MATCHED_GAME        TOP SOLO      Ornn     16  10534  135      14
# 8   CLASSIC MATCHED_GAME     MIDDLE SOLO    Akshan     16  12892  184      21
# 9   CLASSIC MATCHED_GAME        TOP NONE     Teemo     18  18128  221      15
# 10  CLASSIC MATCHED_GAME        TOP SOLO      Ornn     12   6649   90      15
# 11  CLASSIC MATCHED_GAME        TOP SOLO      Ornn     14   9874  143       9
# 12  CLASSIC MATCHED_GAME        TOP SOLO      Ornn     17  11570  201      14
# 13  CLASSIC MATCHED_GAME     TOP SUPPORT      Ornn     11   5452   95       6
# 14  CLASSIC MATCHED_GAME        TOP SOLO      Ornn     18  18398  304      13
# 15     ARAM MATCHED_GAME         SUPPORT     Ziggs     13   9193   29       0
# 16  CLASSIC MATCHED_GAME        TOP SOLO      Ornn     17  13236  161      22
# 17     ARAM MATCHED_GAME  MIDDLE SUPPORT     Kayle     18  23569  144       0
# 18  CLASSIC MATCHED_GAME       TOP CARRY     Teemo     18  15756  253      34
# 19     ARAM MATCHED_GAME      BOTTOM DUO     Teemo     18  15207   55       0
#
#      deal    win
# 0    4017  False
# 1   18751   True
# 2   10095  False
# 3   15753   True
# 4    6808  False
# 5   20377  False
# 6    9870   True
# 7   15418   True
# 8   17075  False
# 9   36506   True
# 10  11935  False
# 11  14591   True
# 12  19075   True
# 13   4828   True
# 14  24767  False
# 15  15611  False
# 16  22420  False
# 17  41503   True
# 18  26785  False
# 19  19374  False

# %% [markdown]
# # 결과물

# %%
df
# Out:
#    result champ       kda                                               item  \
# 0      패배    오른     0/6/3                 도란의 방패, 거인의 허리띠, 점화석, 덤불 조끼, 판금 장화
# 1      승리  볼리베어     3/5/3      도란의 검, 신성한 파괴자, 루비 수정, 탐식의 망치, 곡괭이, 헤르메스의 발걸음
# 2      패배    오른     1/9/4                     덤불 조끼, 서리벼림 손아귀, 증오의 사슬, 판금 장화
# 3      승리  볼리베어     5/6/5                     스테락의 도전, 신성한 파괴자, 판금 장화, 덤불 조끼
# 4      패배   파이크     6/9/5             드락사르의 황혼검, 징수의 총, 톱날 단검, 명석함의 아이오니아 장화
# 5      패배  볼리베어    4/8/10             가시 갑옷, 신성한 파괴자, 헤르메스의 발걸음, 곡괭이, 탐식의 망치
# 6      승리    오른    2/3/12      덤불 조끼, 터보 충전 마공학 실험장치, 증오의 사슬, 거인의 허리띠, 판금 장화
# 7      승리    오른    3/3/14  도란의 방패, 터보 충전 마공학 실험장치, 증오의 사슬, 가시 갑옷, 얼음 방패, ...
# 8      패배   아크샨     9/7/3  도란의 검, 크라켄 학살자, 마법사의 최후, 몰락한 왕의 검, 톱날 단검, 광전사의 군화
# 9      승리    티모    13/7/6   도란의 반지, 내셔의 이빨, 균열 생성기, 악마의 포옹, 마법사의 최후, 광전사의 군화
# 10     패배    오른     3/6/1      덤불 조끼, 마법무효화의 망토, 증오의 사슬, 바미의 불씨, 천 갑옷, 판금 장화
# 11     승리    오른     8/0/6       도란의 방패, 터보 충전 마공학 실험장치, 증오의 사슬, 가시 갑옷, 판금 장화
# 12     승리    오른     3/3/9  가시 갑옷, 터보 충전 마공학 실험장치, 증오의 사슬, 파수꾼의 갑옷, 얼음 방패,...
# 13     승리    오른     3/0/2            도란의 방패, 바미의 불씨, 증오의 사슬, 천 갑옷, 헤르메스의 발걸음
# 14     패배    오른   11/7/12  증오의 사슬, 터보 충전 마공학 실험장치, 가고일 돌갑옷, 가시 갑옷, 워모그의 갑...
# 15     패배    직스    7/6/10          리안드리의 고뇌, 마법사의 신발, 악마의 포옹, 여신의 눈물, 증폭의 고서
# 16     패배    오른    7/5/12  가시 갑옷, 란두인의 예언, 얼어붙은 심장, 판금 장화, 서리벼림 손아귀, 수정 팔...
# 17     승리    케일  14/16/38  균열 생성기, 내셔의 이빨, 헤르메스의 발걸음, 몰락한 왕의 검, 리치베인, 마법사...
# 18     패배    티모    4/11/9  균열 생성기, 존야의 모래시계, 내셔의 이빨, 마법사의 최후, 거인의 허리띠, 광전...
# 19     패배    티모   7/12/20  균열 생성기, 존야의 모래시계, 리치베인, 내셔의 이빨, 거인의 허리띠, 명석함의 ...
#
#          rune
# 0   봉인 풀린 주문서
# 1       집중 공격
# 2   봉인 풀린 주문서
# 3       집중 공격
# 4      어둠의 수확
# 5       집중 공격
# 6   봉인 풀린 주문서
# 7   봉인 풀린 주문서
# 8       집중 공격
# 9       집중 공격
# 10    착취의 손아귀
# 11    착취의 손아귀
# 12  봉인 풀린 주문서
# 13  봉인 풀린 주문서
# 14  봉인 풀린 주문서
# 15    신비로운 유성
# 16  봉인 풀린 주문서
# 17      집중 공격
# 18      집중 공격
# 19     어둠의 수확

# %%
df2
# Out:
#                     mode            role     champ  level   gold   cs  vision  \
# 0   CLASSIC MATCHED_GAME     TOP SUPPORT      Ornn     10   4197   81       7
# 1   CLASSIC MATCHED_GAME        TOP SOLO  Volibear     15   8776  136      15
# 2   CLASSIC MATCHED_GAME        TOP SOLO      Ornn     13   7749  124      21
# 3   CLASSIC MATCHED_GAME        TOP SOLO  Volibear     14   8859  105      13
# 4      ARAM MATCHED_GAME         SUPPORT      Pyke     12   8832    5       0
# 5   CLASSIC MATCHED_GAME        TOP SOLO  Volibear     15   9512  121      14
# 6   CLASSIC MATCHED_GAME        TOP SOLO      Ornn     15   8485  110       6
# 7   CLASSIC MATCHED_GAME        TOP SOLO      Ornn     16  10534  135      14
# 8   CLASSIC MATCHED_GAME     MIDDLE SOLO    Akshan     16  12892  184      21
# 9   CLASSIC MATCHED_GAME        TOP NONE     Teemo     18  18128  221      15
# 10  CLASSIC MATCHED_GAME        TOP SOLO      Ornn     12   6649   90      15
# 11  CLASSIC MATCHED_GAME        TOP SOLO      Ornn     14   9874  143       9
# 12  CLASSIC MATCHED_GAME        TOP SOLO      Ornn     17  11570  201      14
# 13  CLASSIC MATCHED_GAME     TOP SUPPORT      Ornn     11   5452   95       6
# 14  CLASSIC MATCHED_GAME        TOP SOLO      Ornn     18  18398  304      13
# 15     ARAM MATCHED_GAME         SUPPORT     Ziggs     13   9193   29       0
# 16  CLASSIC MATCHED_GAME        TOP SOLO      Ornn     17  13236  161      22
# 17     ARAM MATCHED_GAME  MIDDLE SUPPORT     Kayle     18  23569  144       0
# 18  CLASSIC MATCHED_GAME       TOP CARRY     Teemo     18  15756  253      34
# 19     ARAM MATCHED_GAME      BOTTOM DUO     Teemo     18  15207   55       0
#
#      deal    win
# 0    4017  False
# 1   18751   True
# 2   10095  False
# 3   15753   True
# 4    6808  False
# 5   20377  False
# 6    9870   True
# 7   15418   True
# 8   17075  False
# 9   36506   True
# 10  11935  False
# 11  14591   True
# 12  19075   True
# 13   4828   True
# 14  24767  False
# 15  15611  False
# 16  22420  False
# 17  41503   True
# 18  26785  False
# 19  19374  False
